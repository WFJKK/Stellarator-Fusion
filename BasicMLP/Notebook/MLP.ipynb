# %%
import torch

# --- Hyperparameters ---
subset_hyperparam = None #None means all samples
learning_rate = 1e-3
batch_size = 128
epochs = 30
dropout_prob = 0.2
weight_decay = 1e-4

# --- Device selection ---
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print("Using device:", device)
# Out:
# Using device: cuda

# %%
import torch.nn as nn

class StellaratorNet(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 1),
            nn.Softplus()
        )

    def forward(self, x):
        return self.model(x)

# %%
import numpy as np
from torch.utils.data import Dataset, DataLoader
from datasets import load_dataset
import math


def is_valid(example):
    """Check if an example contains all required metrics with valid values."""
    required_metrics = [
        'metrics.max_elongation',
        'metrics.average_triangularity',
        'metrics.edge_rotational_transform_over_n_field_periods',
        'boundary.n_field_periods',
        'metrics.aspect_ratio',
        'boundary.z_sin',
        'boundary.r_cos'
    ]
    for key in required_metrics:
        val = example.get(key, None)
        if val is None:
            return False
        if isinstance(val, (int, float)):
            if math.isnan(val):
                return False
        elif isinstance(val, list):
            if len(val) == 0:
                return False
            if all(isinstance(row, list) and len(row) > 0 for row in val) is False:
                return False
        else:
            return False
    return True


def load_constellaration_dataset(subset_hyperparam=None, split_ratio=0.8, seed=42):
    dataset = load_dataset("proxima-fusion/constellaration", "default")
    data = dataset["train"]

    # Filter invalid examples first
    data = data.filter(is_valid)

    # Optionally subset first N valid examples
    if subset_hyperparam is not None:
        data = data.select(range(min(subset_hyperparam, len(data))))

    # Shuffle indices
    indices = torch.arange(len(data))
    torch.manual_seed(seed)
    indices = indices[torch.randperm(len(indices))]

    # Split into train/test
    split = int(split_ratio * len(indices))
    train_idx, test_idx = indices[:split], indices[split:]

    train_dataset = data.select(train_idx.tolist())
    test_dataset = data.select(test_idx.tolist())

    return train_dataset, test_dataset


class ConstellarationDataset(Dataset):
    """
    Custom Dataset that separates optimizable features (r_cos, z_sin)
    from fixed features for post-training optimization.
    """
    def __init__(self, hf_dataset, separate_optimizable=False):
        """
        Args:
            hf_dataset: HuggingFace dataset
            separate_optimizable: If True, returns (optimizable_features, fixed_features, target)
                                 If False, returns (all_features, target) for training
        """
        self.data = []
        self.separate_optimizable = separate_optimizable

        # Pre-process and store as numpy arrays
        for sample in hf_dataset:
            try:
                # Extract optimizable features
                r_cos = np.array(sample["boundary.r_cos"], dtype=np.float32).flatten()
                z_sin = np.array(sample["boundary.z_sin"], dtype=np.float32).flatten()

                # Extract fixed features
                fixed_metrics = np.array([
                    float(sample["metrics.aspect_ratio"]),
                    float(sample["metrics.average_triangularity"]),
                    float(sample["metrics.edge_rotational_transform_over_n_field_periods"])
                ], dtype=np.float32)

                target = float(sample["metrics.max_elongation"])

                # Store separately for flexibility
                self.data.append({
                    'r_cos': r_cos,
                    'z_sin': z_sin,
                    'fixed': fixed_metrics,
                    'target': target
                })
            except Exception as e:
                print(f"Error processing sample: {e}")
                continue

        if len(self.data) == 0:
            raise ValueError("No valid samples found in dataset")

        # Store feature dimensions for later use
        sample = self.data[0]
        self.r_cos_dim = len(sample['r_cos'])
        self.z_sin_dim = len(sample['z_sin'])
        self.fixed_dim = len(sample['fixed'])

        print(f"Successfully loaded {len(self.data)} samples")
        #print(f"Feature dimensions - r_cos: {self.r_cos_dim}, z_sin: {self.z_sin_dim}, fixed: {self.fixed_dim}")

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = self.data[idx]

        if self.separate_optimizable:
            # For optimization: return optimizable and fixed features separately
            optimizable = np.concatenate([sample['r_cos'], sample['z_sin']])
            return (
                torch.from_numpy(optimizable),
                torch.from_numpy(sample['fixed']),
                torch.tensor(sample['target'], dtype=torch.float32)
            )
        else:
            # For training: return all features concatenated
            features = np.concatenate([sample['r_cos'], sample['z_sin'], sample['fixed']])
            return (
                torch.from_numpy(features),
                torch.tensor(sample['target'], dtype=torch.float32)
            )


def collate_fn(batch):
    """Custom collate function that handles both training and optimization modes."""
    if len(batch[0]) == 3:
        # Optimization mode: (optimizable, fixed, target)
        optimizable, fixed, targets = zip(*batch)
        return (
            torch.stack(optimizable),
            torch.stack(fixed),
            torch.stack(targets).reshape(-1, 1)
        )
    else:
        # Training mode: (features, target)
        features, targets = zip(*batch)
        return torch.stack(features), torch.stack(targets).reshape(-1, 1)


# Example usage for training
def create_training_dataloader(train_dataset, batch_size=32):
    """Create dataloader for training with all features concatenated."""
    dataset = ConstellarationDataset(train_dataset, separate_optimizable=False)
    return DataLoader(dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)


# Example usage for optimization
def create_optimization_dataloader(test_dataset, batch_size=32):
    """Create dataloader for optimization with features separated."""
    dataset = ConstellarationDataset(test_dataset, separate_optimizable=True)
    return DataLoader(dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

# %%
import torch.optim as optim
def train_model(model=None, train_loader=None, test_loader=None, num_epochs=epochs, lr=learning_rate, save_path="best_model.pth"):
    """
    Trains the model and saves the weights with the best test loss.
    Args:
        model (nn.Module): PyTorch model to train
        train_loader (DataLoader): Training data loader
        test_loader (DataLoader): Test/validation data loader
        num_epochs (int): Number of training epochs
        lr (float): Learning rate
        save_path (str): Path to save the best model weights
    Returns:
        model: Trained PyTorch model
    """
    # If no model is provided, create one
    if model is None:
        train_data, _ = load_constellaration_dataset()
        # Use separate_optimizable=False for training
        train_dataset = ConstellarationDataset(train_data, separate_optimizable=False)
        input_dim = train_dataset[0][0].shape[0]
        model = StellaratorNet(input_dim).to(device)

    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

    best_test_loss = float("inf")

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0

        for features, targets in train_loader:
            features, targets = features.to(device), targets.to(device)

            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * features.size(0)

        train_loss /= len(train_loader.dataset)

        # --- Evaluation ---
        model.eval()
        test_loss = 0.0
        with torch.no_grad():
            for features, targets in test_loader:
                features, targets = features.to(device), targets.to(device)
                outputs = model(features)
                loss = criterion(outputs, targets)
                test_loss += loss.item() * features.size(0)

        test_loss /= len(test_loader.dataset)

        print(f"Epoch {epoch+1}/{num_epochs} | Train Loss: {train_loss:.4f} | Test Loss: {test_loss:.4f}")

        # Save model if test loss improved
        if test_loss < best_test_loss:
            best_test_loss = test_loss
            torch.save(model.state_dict(), save_path)
            print(f"Saved best model with test loss {best_test_loss:.4f} at epoch {epoch+1}")

    # Load best model weights before returning
    model.load_state_dict(torch.load(save_path))
    return model


def get_dataloaders(batch_size=batch_size, separate_optimizable=False):
    """
    Get dataloaders for training or optimization.

    Args:
        batch_size (int): Batch size
        separate_optimizable (bool): If False, returns concatenated features for training.
                                    If True, returns separated features for optimization.

    Returns:
        train_loader, test_loader: DataLoaders
    """
    train_data, test_data = load_constellaration_dataset(subset_hyperparam=None)

    train_dataset = ConstellarationDataset(train_data, separate_optimizable=separate_optimizable)
    test_dataset = ConstellarationDataset(test_data, separate_optimizable=separate_optimizable)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

    return train_loader, test_loader


def get_feature_dimensions():
    """
    Helper function to get feature dimensions for optimization setup.

    Returns:
        dict: Dictionary with r_cos_dim, z_sin_dim, fixed_dim
    """
    # Load enough samples to ensure we get at least one valid sample
    train_data, _ = load_constellaration_dataset(subset_hyperparam=100)
    train_dataset = ConstellarationDataset(train_data, separate_optimizable=False)

    return {
        'r_cos_dim': train_dataset.r_cos_dim,
        'z_sin_dim': train_dataset.z_sin_dim,
        'fixed_dim': train_dataset.fixed_dim,
        'total_dim': train_dataset.r_cos_dim + train_dataset.z_sin_dim + train_dataset.fixed_dim
    }


def get_feature_dimensions_from_dataset(dataset):
    """
    Alternative: Get dimensions from an existing dataset instance.

    Args:
        dataset: ConstellarationDataset instance

    Returns:
        dict: Dictionary with r_cos_dim, z_sin_dim, fixed_dim
    """
    return {
        'r_cos_dim': dataset.r_cos_dim,
        'z_sin_dim': dataset.z_sin_dim,
        'fixed_dim': dataset.fixed_dim,
        'total_dim': dataset.r_cos_dim + dataset.z_sin_dim + dataset.fixed_dim
    }

# %%
# Get data loaders
train_loader, test_loader = get_dataloaders()

# Initialize model
input_dim = train_loader.dataset[0][0].shape[0]
model = StellaratorNet(input_dim).to(device)

# Train the model
trained_model = train_model(model=model, train_loader=train_loader, test_loader=test_loader, num_epochs=epochs)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00003.parquet:   0%|          | 0.00/252M [00:00<?, ?B/s]
# data/train-00001-of-00003.parquet:   0%|          | 0.00/204M [00:00<?, ?B/s]
# data/train-00002-of-00003.parquet:   0%|          | 0.00/155M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/182222 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/182222 [00:00<?, ? examples/s]
# Successfully loaded 126948 samples
# Successfully loaded 31737 samples
# Epoch 1/30 | Train Loss: 2.1151 | Test Loss: 0.9890
# Saved best model with test loss 0.9890 at epoch 1
# Epoch 2/30 | Train Loss: 1.1409 | Test Loss: 0.7500
# Saved best model with test loss 0.7500 at epoch 2
# Epoch 3/30 | Train Loss: 0.9824 | Test Loss: 0.6399
# Saved best model with test loss 0.6399 at epoch 3
# Epoch 4/30 | Train Loss: 0.8785 | Test Loss: 0.5385
# Saved best model with test loss 0.5385 at epoch 4
# Epoch 5/30 | Train Loss: 0.7892 | Test Loss: 0.5136
# Saved best model with test loss 0.5136 at epoch 5
# Epoch 6/30 | Train Loss: 0.7201 | Test Loss: 0.4040
# Saved best model with test loss 0.4040 at epoch 6
# Epoch 7/30 | Train Loss: 0.6697 | Test Loss: 0.3582
# Saved best model with test loss 0.3582 at epoch 7
# Epoch 8/30 | Train Loss: 0.6353 | Test Loss: 0.3341
# Saved best model with test loss 0.3341 at epoch 8
# Epoch 9/30 | Train Loss: 0.5977 | Test Loss: 0.3159
# Saved best model with test loss 0.3159 at epoch 9
# Epoch 10/30 | Train Loss: 0.5817 | Test Loss: 0.3063
# Saved best model with test loss 0.3063 at epoch 10
# Epoch 11/30 | Train Loss: 0.5597 | Test Loss: 0.2769
# Saved best model with test loss 0.2769 at epoch 11
# Epoch 12/30 | Train Loss: 0.5388 | Test Loss: 0.2694
# Saved best model with test loss 0.2694 at epoch 12
# Epoch 13/30 | Train Loss: 0.5279 | Test Loss: 0.2504
# Saved best model with test loss 0.2504 at epoch 13
# Epoch 14/30 | Train Loss: 0.5077 | Test Loss: 0.2325
# Saved best model with test loss 0.2325 at epoch 14
# Epoch 15/30 | Train Loss: 0.4986 | Test Loss: 0.2328
# Epoch 16/30 | Train Loss: 0.4909 | Test Loss: 0.2341
# Epoch 17/30 | Train Loss: 0.4817 | Test Loss: 0.2130
# Saved best model with test loss 0.2130 at epoch 17
# Epoch 18/30 | Train Loss: 0.4726 | Test Loss: 0.2069
# Saved best model with test loss 0.2069 at epoch 18
# Epoch 19/30 | Train Loss: 0.4711 | Test Loss: 0.2222
# Epoch 20/30 | Train Loss: 0.4606 | Test Loss: 0.2113
# Epoch 21/30 | Train Loss: 0.4538 | Test Loss: 0.2059
# Saved best model with test loss 0.2059 at epoch 21
# Epoch 22/30 | Train Loss: 0.4525 | Test Loss: 0.2142
# Epoch 23/30 | Train Loss: 0.4405 | Test Loss: 0.1944
# Saved best model with test loss 0.1944 at epoch 23
# Epoch 24/30 | Train Loss: 0.4323 | Test Loss: 0.2822
# Epoch 25/30 | Train Loss: 0.4396 | Test Loss: 0.2051
# Epoch 26/30 | Train Loss: 0.4259 | Test Loss: 0.2067
# Epoch 27/30 | Train Loss: 0.4286 | Test Loss: 0.1909
# Saved best model with test loss 0.1909 at epoch 27
# Epoch 28/30 | Train Loss: 0.4199 | Test Loss: 0.1830
# Saved best model with test loss 0.1830 at epoch 28
# Epoch 29/30 | Train Loss: 0.4194 | Test Loss: 0.2015
# Epoch 30/30 | Train Loss: 0.4120 | Test Loss: 0.2153

# %%
#Now we come to the optimization
# --- Hyperparameters ---
iterations = 20
lr_opti = 1e-3



def optimize_features(model_path, num_iterations=10, lr=0.01, batch_size=32):
    """
    Optimize r_cos and z_sin features to minimize the target (max_elongation)
    while keeping other features fixed.

    Args:
        model_path (str): Path to trained model weights
        num_iterations (int): Number of optimization iterations
        lr (float): Learning rate for feature optimization
        batch_size (int): Batch size

    Returns:
        optimized_features: Dictionary with optimized r_cos and z_sin for each sample
    """
    # Get data with separated features first
    _, test_data = load_constellaration_dataset()
    test_dataset = ConstellarationDataset(test_data, separate_optimizable=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

    # Get dimensions from the dataset
    dims = {
        'r_cos_dim': test_dataset.r_cos_dim,
        'z_sin_dim': test_dataset.z_sin_dim,
        'fixed_dim': test_dataset.fixed_dim,
        'total_dim': test_dataset.r_cos_dim + test_dataset.z_sin_dim + test_dataset.fixed_dim
    }

    # Load trained model
    model = StellaratorNet(dims['total_dim']).to(device)
    model.load_state_dict(torch.load(model_path))
    model.eval()  # Set to eval mode - we're not training the model



    all_results = []

    # Process each batch
    for batch_idx, (optimizable, fixed, targets) in enumerate(test_loader):
        optimizable = optimizable.to(device)
        fixed = fixed.to(device)
        targets = targets.to(device)

        # Create optimizable parameters - detach from original and require grad
        optimizable_params = optimizable.clone().detach().requires_grad_(True)

        # Use Adam optimizer for the features
        optimizer = optim.Adam([optimizable_params], lr=lr)

        initial_loss = None

        # Optimize this batch
        for iteration in range(num_iterations):
            optimizer.zero_grad()

            # Concatenate optimizable and fixed features
            combined_features = torch.cat([optimizable_params, fixed], dim=1)

            # Forward pass through model
            predictions = model(combined_features)

            # Loss: we want to minimize the prediction (max_elongation)
            loss = predictions.mean()

            if iteration == 0:
                initial_loss = loss.item()

            # Backward pass - only optimizable_params will get gradients
            loss.backward()
            optimizer.step()

            if (iteration + 1) % 100 == 0:
                print(f"Batch {batch_idx+1}, Iteration {iteration+1}/{num_iterations}, Loss: {loss.item():.6f}")

        final_loss = loss.item()
        print(f"Batch {batch_idx+1} - Initial: {initial_loss:.6f}, Final: {final_loss:.6f}, "
              f"Improvement: {(initial_loss - final_loss):.6f}")

        # Store results
        r_cos_dim = dims['r_cos_dim']
        optimized_r_cos = optimizable_params[:, :r_cos_dim].detach().cpu()
        optimized_z_sin = optimizable_params[:, r_cos_dim:].detach().cpu()

        all_results.append({
            'r_cos': optimized_r_cos,
            'z_sin': optimized_z_sin,
            'fixed': fixed.cpu(),
            'original_target': targets.cpu(),
            'initial_prediction': initial_loss,
            'final_prediction': final_loss
        })

    return all_results

# %%
results = optimize_features(model_path="best_model.pth", num_iterations=iterations, lr=lr_opti, batch_size=batch_size)
torch.save(results, "optimized_features.pt")
print("Saved optimized features to optimized_features.pt")
# Out:
# Successfully loaded 31737 samples
# Batch 1 - Initial: 4.655895, Final: 0.632839, Improvement: 4.023057
# Batch 2 - Initial: 5.056080, Final: 0.663935, Improvement: 4.392145
# Batch 3 - Initial: 4.895375, Final: 0.674048, Improvement: 4.221327
# Batch 4 - Initial: 4.889223, Final: 0.633327, Improvement: 4.255896
# Batch 5 - Initial: 4.822328, Final: 0.616691, Improvement: 4.205637
# Batch 6 - Initial: 4.919339, Final: 0.709233, Improvement: 4.210106
# Batch 7 - Initial: 4.856818, Final: 0.693722, Improvement: 4.163096
# Batch 8 - Initial: 4.537639, Final: 0.648044, Improvement: 3.889595
# Batch 9 - Initial: 4.703805, Final: 0.685797, Improvement: 4.018008
# Batch 10 - Initial: 4.811751, Final: 0.582422, Improvement: 4.229330
# Batch 11 - Initial: 4.897969, Final: 0.675318, Improvement: 4.222652
# Batch 12 - Initial: 4.668969, Final: 0.630481, Improvement: 4.038488
# Batch 13 - Initial: 4.891409, Final: 0.666493, Improvement: 4.224915
# Batch 14 - Initial: 4.763196, Final: 0.670775, Improvement: 4.092421
# Batch 15 - Initial: 4.589388, Final: 0.640160, Improvement: 3.949228
# Batch 16 - Initial: 4.703477, Final: 0.666105, Improvement: 4.037371
# Batch 17 - Initial: 4.786720, Final: 0.716058, Improvement: 4.070662
# Batch 18 - Initial: 4.575047, Final: 0.641340, Improvement: 3.933706
# Batch 19 - Initial: 4.922088, Final: 0.671919, Improvement: 4.250168
# Batch 20 - Initial: 4.992022, Final: 0.698345, Improvement: 4.293677
# Batch 21 - Initial: 4.653976, Final: 0.578167, Improvement: 4.075810
# Batch 22 - Initial: 4.932372, Final: 0.665493, Improvement: 4.266879
# Batch 23 - Initial: 4.837294, Final: 0.601450, Improvement: 4.235844
# Batch 24 - Initial: 4.708797, Final: 0.622395, Improvement: 4.086403
# Batch 25 - Initial: 4.851718, Final: 0.693597, Improvement: 4.158121
# Batch 26 - Initial: 4.532488, Final: 0.611505, Improvement: 3.920983
# Batch 27 - Initial: 4.907856, Final: 0.667965, Improvement: 4.239891
# Batch 28 - Initial: 4.905237, Final: 0.722946, Improvement: 4.182290
# Batch 29 - Initial: 4.859265, Final: 0.729522, Improvement: 4.129743
# Batch 30 - Initial: 4.656342, Final: 0.644906, Improvement: 4.011435
# Batch 31 - Initial: 4.734336, Final: 0.607023, Improvement: 4.127313
# Batch 32 - Initial: 4.743746, Final: 0.644210, Improvement: 4.099536
# Batch 33 - Initial: 4.623137, Final: 0.557772, Improvement: 4.065366
# Batch 34 - Initial: 5.042281, Final: 0.629286, Improvement: 4.412995
# Batch 35 - Initial: 4.657651, Final: 0.690951, Improvement: 3.966700
# Batch 36 - Initial: 4.641801, Final: 0.548562, Improvement: 4.093239
# Batch 37 - Initial: 4.653506, Final: 0.624915, Improvement: 4.028591
# Batch 38 - Initial: 4.876482, Final: 0.725147, Improvement: 4.151334
# Batch 39 - Initial: 4.718039, Final: 0.654900, Improvement: 4.063138
# Batch 40 - Initial: 4.959884, Final: 0.730327, Improvement: 4.229557
# Batch 41 - Initial: 5.062655, Final: 0.682225, Improvement: 4.380430
# Batch 42 - Initial: 4.793712, Final: 0.668337, Improvement: 4.125375
# Batch 43 - Initial: 4.899257, Final: 0.682338, Improvement: 4.216919
# Batch 44 - Initial: 4.732928, Final: 0.631260, Improvement: 4.101668
# Batch 45 - Initial: 4.781931, Final: 0.687758, Improvement: 4.094173
# Batch 46 - Initial: 4.774390, Final: 0.660739, Improvement: 4.113651
# Batch 47 - Initial: 4.743183, Final: 0.687411, Improvement: 4.055773
# Batch 48 - Initial: 4.884850, Final: 0.679469, Improvement: 4.205381
# Batch 49 - Initial: 4.757096, Final: 0.623343, Improvement: 4.133754
# Batch 50 - Initial: 4.813930, Final: 0.556896, Improvement: 4.257034
# Batch 51 - Initial: 5.070865, Final: 0.679741, Improvement: 4.391124
# Batch 52 - Initial: 4.879373, Final: 0.594903, Improvement: 4.284470
# Batch 53 - Initial: 4.669578, Final: 0.717302, Improvement: 3.952275
# Batch 54 - Initial: 4.794025, Final: 0.639944, Improvement: 4.154081
# Batch 55 - Initial: 4.699408, Final: 0.602505, Improvement: 4.096902
# Batch 56 - Initial: 4.990677, Final: 0.686385, Improvement: 4.304292
# Batch 57 - Initial: 4.634534, Final: 0.643667, Improvement: 3.990866
# Batch 58 - Initial: 4.852824, Final: 0.668068, Improvement: 4.184756
# Batch 59 - Initial: 4.776656, Final: 0.649540, Improvement: 4.127116
# Batch 60 - Initial: 4.858850, Final: 0.623166, Improvement: 4.235683
# Batch 61 - Initial: 4.912327, Final: 0.694574, Improvement: 4.217753
# Batch 62 - Initial: 4.931945, Final: 0.633816, Improvement: 4.298129
# Batch 63 - Initial: 4.705614, Final: 0.624997, Improvement: 4.080617
# Batch 64 - Initial: 4.927834, Final: 0.681097, Improvement: 4.246737
# Batch 65 - Initial: 4.682777, Final: 0.616695, Improvement: 4.066082
# Batch 66 - Initial: 5.036414, Final: 0.729343, Improvement: 4.307071
# Batch 67 - Initial: 4.961054, Final: 0.735202, Improvement: 4.225852
# Batch 68 - Initial: 4.596874, Final: 0.601289, Improvement: 3.995585
# Batch 69 - Initial: 4.742808, Final: 0.639330, Improvement: 4.103478
# Batch 70 - Initial: 4.883777, Final: 0.674296, Improvement: 4.209481
# Batch 71 - Initial: 5.115520, Final: 0.685542, Improvement: 4.429977
# Batch 72 - Initial: 4.760180, Final: 0.615507, Improvement: 4.144673
# Batch 73 - Initial: 4.854632, Final: 0.674597, Improvement: 4.180035
# Batch 74 - Initial: 5.035469, Final: 0.621120, Improvement: 4.414349
# Batch 75 - Initial: 4.865978, Final: 0.612292, Improvement: 4.253686
# Batch 76 - Initial: 4.720778, Final: 0.592975, Improvement: 4.127803
# Batch 77 - Initial: 4.857535, Final: 0.684035, Improvement: 4.173500
# Batch 78 - Initial: 4.946438, Final: 0.699747, Improvement: 4.246691
# Batch 79 - Initial: 4.813442, Final: 0.645984, Improvement: 4.167458
# Batch 80 - Initial: 4.864467, Final: 0.651140, Improvement: 4.213327
# Batch 81 - Initial: 4.883754, Final: 0.640689, Improvement: 4.243065
# Batch 82 - Initial: 4.859112, Final: 0.639082, Improvement: 4.220030
# Batch 83 - Initial: 4.803040, Final: 0.658580, Improvement: 4.144459
# Batch 84 - Initial: 4.672140, Final: 0.660939, Improvement: 4.011202
# Batch 85 - Initial: 5.045572, Final: 0.676188, Improvement: 4.369384
# Batch 86 - Initial: 4.904514, Final: 0.631287, Improvement: 4.273228
# Batch 87 - Initial: 4.806857, Final: 0.669908, Improvement: 4.136949
# Batch 88 - Initial: 4.870430, Final: 0.640404, Improvement: 4.230026
# Batch 89 - Initial: 4.684810, Final: 0.664492, Improvement: 4.020318
# Batch 90 - Initial: 4.856505, Final: 0.642888, Improvement: 4.213617
# Batch 91 - Initial: 4.573309, Final: 0.569631, Improvement: 4.003678
# Batch 92 - Initial: 4.761436, Final: 0.642401, Improvement: 4.119036
# Batch 93 - Initial: 4.723822, Final: 0.630141, Improvement: 4.093680
# Batch 94 - Initial: 4.867692, Final: 0.589870, Improvement: 4.277822
# Batch 95 - Initial: 4.944712, Final: 0.642655, Improvement: 4.302057
# Batch 96 - Initial: 4.817060, Final: 0.621528, Improvement: 4.195532
# Batch 97 - Initial: 4.590055, Final: 0.606760, Improvement: 3.983295
# Batch 98 - Initial: 4.616141, Final: 0.620538, Improvement: 3.995603
# Batch 99 - Initial: 4.812885, Final: 0.682696, Improvement: 4.130189
# Batch 100 - Initial: 4.712781, Final: 0.622097, Improvement: 4.090684
# Batch 101 - Initial: 4.663085, Final: 0.600957, Improvement: 4.062129
# Batch 102 - Initial: 4.868185, Final: 0.698212, Improvement: 4.169973
# Batch 103 - Initial: 4.710754, Final: 0.694098, Improvement: 4.016655
# Batch 104 - Initial: 4.660411, Final: 0.639258, Improvement: 4.021153
# Batch 105 - Initial: 4.839170, Final: 0.641013, Improvement: 4.198157
# Batch 106 - Initial: 4.968384, Final: 0.668693, Improvement: 4.299691
# Batch 107 - Initial: 4.608789, Final: 0.647728, Improvement: 3.961061
# Batch 108 - Initial: 4.774803, Final: 0.605971, Improvement: 4.168832
# Batch 109 - Initial: 4.720402, Final: 0.641849, Improvement: 4.078553
# Batch 110 - Initial: 4.719625, Final: 0.632368, Improvement: 4.087257
# Batch 111 - Initial: 4.631199, Final: 0.598067, Improvement: 4.033132
# Batch 112 - Initial: 4.873244, Final: 0.634976, Improvement: 4.238268
# Batch 113 - Initial: 4.900743, Final: 0.602323, Improvement: 4.298421
# Batch 114 - Initial: 4.827309, Final: 0.637724, Improvement: 4.189584
# Batch 115 - Initial: 4.879615, Final: 0.677736, Improvement: 4.201879
# Batch 116 - Initial: 4.833337, Final: 0.645937, Improvement: 4.187400
# Batch 117 - Initial: 4.773559, Final: 0.673787, Improvement: 4.099771
# Batch 118 - Initial: 4.915660, Final: 0.636860, Improvement: 4.278800
# Batch 119 - Initial: 4.859100, Final: 0.699837, Improvement: 4.159263
# Batch 120 - Initial: 4.995142, Final: 0.658740, Improvement: 4.336402
# Batch 121 - Initial: 4.967300, Final: 0.698815, Improvement: 4.268485
# Batch 122 - Initial: 4.908912, Final: 0.718264, Improvement: 4.190648
# Batch 123 - Initial: 4.861630, Final: 0.686529, Improvement: 4.175102
# Batch 124 - Initial: 4.722108, Final: 0.666479, Improvement: 4.055629
# Batch 125 - Initial: 4.895281, Final: 0.695240, Improvement: 4.200041
# Batch 126 - Initial: 4.600917, Final: 0.562089, Improvement: 4.038829
# Batch 127 - Initial: 4.655880, Final: 0.582332, Improvement: 4.073548
# Batch 128 - Initial: 4.690178, Final: 0.657638, Improvement: 4.032540
# Batch 129 - Initial: 4.831914, Final: 0.672345, Improvement: 4.159569
# Batch 130 - Initial: 4.614022, Final: 0.621942, Improvement: 3.992080
# Batch 131 - Initial: 5.092052, Final: 0.654145, Improvement: 4.437907
# Batch 132 - Initial: 4.807334, Final: 0.625713, Improvement: 4.181621
# Batch 133 - Initial: 4.987013, Final: 0.617089, Improvement: 4.369924
# Batch 134 - Initial: 4.985165, Final: 0.660481, Improvement: 4.324683
# Batch 135 - Initial: 4.759539, Final: 0.690760, Improvement: 4.068779
# Batch 136 - Initial: 4.874934, Final: 0.648939, Improvement: 4.225995
# Batch 137 - Initial: 4.586500, Final: 0.644502, Improvement: 3.941998
# Batch 138 - Initial: 4.780413, Final: 0.585703, Improvement: 4.194709
# Batch 139 - Initial: 4.813932, Final: 0.676319, Improvement: 4.137614
# Batch 140 - Initial: 4.768497, Final: 0.656745, Improvement: 4.111752
# Batch 141 - Initial: 4.738675, Final: 0.569723, Improvement: 4.168952
# Batch 142 - Initial: 4.884756, Final: 0.599762, Improvement: 4.284994
# Batch 143 - Initial: 4.862887, Final: 0.620582, Improvement: 4.242305
# Batch 144 - Initial: 4.963421, Final: 0.746454, Improvement: 4.216967
# Batch 145 - Initial: 4.629767, Final: 0.641199, Improvement: 3.988569
# Batch 146 - Initial: 4.605055, Final: 0.629653, Improvement: 3.975402
# Batch 147 - Initial: 4.769680, Final: 0.584064, Improvement: 4.185616
# Batch 148 - Initial: 4.926314, Final: 0.707489, Improvement: 4.218825
# Batch 149 - Initial: 4.750060, Final: 0.645032, Improvement: 4.105028
# Batch 150 - Initial: 4.769594, Final: 0.676054, Improvement: 4.093540
# Batch 151 - Initial: 4.834353, Final: 0.737396, Improvement: 4.096957
# Batch 152 - Initial: 4.871052, Final: 0.647128, Improvement: 4.223924
# Batch 153 - Initial: 4.575053, Final: 0.596714, Improvement: 3.978339
# Batch 154 - Initial: 5.158759, Final: 0.687240, Improvement: 4.471518
# Batch 155 - Initial: 4.716714, Final: 0.645344, Improvement: 4.071371
# Batch 156 - Initial: 4.860169, Final: 0.648415, Improvement: 4.211754
# Batch 157 - Initial: 4.832603, Final: 0.630300, Improvement: 4.202302
# Batch 158 - Initial: 4.810088, Final: 0.651646, Improvement: 4.158442
# Batch 159 - Initial: 4.920368, Final: 0.694271, Improvement: 4.226096
# Batch 160 - Initial: 4.874347, Final: 0.690666, Improvement: 4.183681
# Batch 161 - Initial: 4.941976, Final: 0.683210, Improvement: 4.258766
# Batch 162 - Initial: 5.182686, Final: 0.659061, Improvement: 4.523625
# Batch 163 - Initial: 4.757259, Final: 0.626372, Improvement: 4.130888
# Batch 164 - Initial: 4.769361, Final: 0.691443, Improvement: 4.077918
# Batch 165 - Initial: 4.766953, Final: 0.642358, Improvement: 4.124595
# Batch 166 - Initial: 4.759520, Final: 0.662112, Improvement: 4.097408
# Batch 167 - Initial: 4.662364, Final: 0.651063, Improvement: 4.011301
# Batch 168 - Initial: 5.024580, Final: 0.696848, Improvement: 4.327732
# Batch 169 - Initial: 4.694747, Final: 0.716592, Improvement: 3.978155
# Batch 170 - Initial: 4.827458, Final: 0.608847, Improvement: 4.218611
# Batch 171 - Initial: 4.676585, Final: 0.625705, Improvement: 4.050880
# Batch 172 - Initial: 4.805384, Final: 0.635080, Improvement: 4.170303
# Batch 173 - Initial: 4.742022, Final: 0.598228, Improvement: 4.143793
# Batch 174 - Initial: 4.765850, Final: 0.709066, Improvement: 4.056784
# Batch 175 - Initial: 5.124824, Final: 0.716955, Improvement: 4.407869
# Batch 176 - Initial: 4.905458, Final: 0.674658, Improvement: 4.230801
# Batch 177 - Initial: 4.601067, Final: 0.642221, Improvement: 3.958845
# Batch 178 - Initial: 4.683673, Final: 0.655147, Improvement: 4.028526
# Batch 179 - Initial: 4.910301, Final: 0.654895, Improvement: 4.255406
# Batch 180 - Initial: 4.513129, Final: 0.651308, Improvement: 3.861821
# Batch 181 - Initial: 4.722552, Final: 0.660950, Improvement: 4.061603
# Batch 182 - Initial: 4.818569, Final: 0.641170, Improvement: 4.177399
# Batch 183 - Initial: 4.733221, Final: 0.658299, Improvement: 4.074922
# Batch 184 - Initial: 4.934284, Final: 0.655784, Improvement: 4.278500
# Batch 185 - Initial: 4.733778, Final: 0.638667, Improvement: 4.095111
# Batch 186 - Initial: 4.744981, Final: 0.692002, Improvement: 4.052979
# Batch 187 - Initial: 4.635312, Final: 0.634018, Improvement: 4.001293
# Batch 188 - Initial: 4.844472, Final: 0.659477, Improvement: 4.184995
# Batch 189 - Initial: 4.926423, Final: 0.639308, Improvement: 4.287115
# Batch 190 - Initial: 5.036516, Final: 0.707245, Improvement: 4.329271
# Batch 191 - Initial: 4.736089, Final: 0.629298, Improvement: 4.106791
# Batch 192 - Initial: 4.719853, Final: 0.675453, Improvement: 4.044401
# Batch 193 - Initial: 4.493839, Final: 0.639342, Improvement: 3.854497
# Batch 194 - Initial: 4.727447, Final: 0.662827, Improvement: 4.064620
# Batch 195 - Initial: 4.717322, Final: 0.637057, Improvement: 4.080266
# Batch 196 - Initial: 4.631215, Final: 0.692990, Improvement: 3.938225
# Batch 197 - Initial: 4.710809, Final: 0.623671, Improvement: 4.087138
# Batch 198 - Initial: 4.817553, Final: 0.663999, Improvement: 4.153554
# Batch 199 - Initial: 5.002706, Final: 0.634952, Improvement: 4.367754
# Batch 200 - Initial: 4.783975, Final: 0.662243, Improvement: 4.121731
# Batch 201 - Initial: 5.009170, Final: 0.683318, Improvement: 4.325852
# Batch 202 - Initial: 4.761604, Final: 0.653958, Improvement: 4.107646
# Batch 203 - Initial: 4.787759, Final: 0.605342, Improvement: 4.182416
# Batch 204 - Initial: 4.951364, Final: 0.659621, Improvement: 4.291743
# Batch 205 - Initial: 4.868982, Final: 0.625814, Improvement: 4.243168
# Batch 206 - Initial: 4.611012, Final: 0.596394, Improvement: 4.014618
# Batch 207 - Initial: 4.816325, Final: 0.694902, Improvement: 4.121423
# Batch 208 - Initial: 4.950758, Final: 0.625289, Improvement: 4.325469
# Batch 209 - Initial: 4.959738, Final: 0.676241, Improvement: 4.283497
# Batch 210 - Initial: 4.960114, Final: 0.662445, Improvement: 4.297670
# Batch 211 - Initial: 4.801934, Final: 0.637249, Improvement: 4.164685
# Batch 212 - Initial: 4.777879, Final: 0.633182, Improvement: 4.144698
# Batch 213 - Initial: 4.950691, Final: 0.680242, Improvement: 4.270449
# Batch 214 - Initial: 4.816772, Final: 0.595810, Improvement: 4.220963
# Batch 215 - Initial: 4.815732, Final: 0.640299, Improvement: 4.175433
# Batch 216 - Initial: 5.101081, Final: 0.713082, Improvement: 4.387999
# Batch 217 - Initial: 4.821959, Final: 0.688566, Improvement: 4.133393
# Batch 218 - Initial: 5.018174, Final: 0.626971, Improvement: 4.391204
# Batch 219 - Initial: 4.768905, Final: 0.598869, Improvement: 4.170036
# Batch 220 - Initial: 4.929778, Final: 0.619084, Improvement: 4.310694
# Batch 221 - Initial: 4.755466, Final: 0.612287, Improvement: 4.143179
# Batch 222 - Initial: 4.630493, Final: 0.634694, Improvement: 3.995798
# Batch 223 - Initial: 4.802189, Final: 0.563273, Improvement: 4.238916
# Batch 224 - Initial: 5.057640, Final: 0.691678, Improvement: 4.365962
# Batch 225 - Initial: 4.682428, Final: 0.589011, Improvement: 4.093417
# Batch 226 - Initial: 4.723172, Final: 0.644990, Improvement: 4.078182
# Batch 227 - Initial: 4.729190, Final: 0.566422, Improvement: 4.162768
# Batch 228 - Initial: 4.647985, Final: 0.629696, Improvement: 4.018288
# Batch 229 - Initial: 4.888072, Final: 0.653728, Improvement: 4.234344
# Batch 230 - Initial: 4.869396, Final: 0.646961, Improvement: 4.222435
# Batch 231 - Initial: 4.722610, Final: 0.673141, Improvement: 4.049469
# Batch 232 - Initial: 4.775601, Final: 0.666083, Improvement: 4.109518
# Batch 233 - Initial: 4.831991, Final: 0.686105, Improvement: 4.145887
# Batch 234 - Initial: 4.804794, Final: 0.652520, Improvement: 4.152275
# Batch 235 - Initial: 4.598751, Final: 0.633064, Improvement: 3.965687
# Batch 236 - Initial: 4.698321, Final: 0.647056, Improvement: 4.051265
# Batch 237 - Initial: 4.721247, Final: 0.682231, Improvement: 4.039016
# Batch 238 - Initial: 4.987851, Final: 0.626062, Improvement: 4.361789
# Batch 239 - Initial: 4.871142, Final: 0.714911, Improvement: 4.156232
# Batch 240 - Initial: 4.977319, Final: 0.693168, Improvement: 4.284151
# Batch 241 - Initial: 4.618888, Final: 0.642352, Improvement: 3.976536
# Batch 242 - Initial: 4.731348, Final: 0.612107, Improvement: 4.119241
# Batch 243 - Initial: 4.641374, Final: 0.639746, Improvement: 4.001628
# Batch 244 - Initial: 4.845118, Final: 0.658946, Improvement: 4.186172
# Batch 245 - Initial: 4.639211, Final: 0.652889, Improvement: 3.986321
# Batch 246 - Initial: 4.837262, Final: 0.664771, Improvement: 4.172491
# Batch 247 - Initial: 4.758489, Final: 0.680004, Improvement: 4.078485
# Batch 248 - Initial: 4.748125, Final: 0.661273, Improvement: 4.086852
# Saved optimized features to optimized_features.pt
